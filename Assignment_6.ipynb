# %% [markdown]
# 1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.
#
# __Ans:-__

# %%
def find_the_difference(s,t):
    freq = dict()
    for i in s:
        freq[i] = freq.get(i, 0) + 1
    
    for j in t:
        freq[j] = freq.get(j, 0) - 1
        if freq[j] == 0:
            freq.pop(j)
    return list(freq.keys())[0]
print(find_the_difference("ae", "eaa"))
print(find_the_difference("", "y"))
# Out:
# a
# y

# %% [markdown]
# ***

# %% [markdown]
# 2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#
#     List order is:
#
#     [int, str, bool, list, tuple, dictionary]
#
# __Ans:-__

# %%
def count_datatypes(*args):
    datatype_dict = dict()
    returned_list = [int, str, bool, list, tuple, dict]
    
    for i in args:
        if datatype_dict.get(type(i), 0):
            datatype_dict.get(type(i)).append(i)
        else:
            datatype_dict[type(i)] = [i]
    
    for index, i in enumerate(returned_list):
        if i in datatype_dict:
            returned_list[index] = len(datatype_dict[i])
        else:
            returned_list[index] = 0
    return returned_list

print(count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]))
print(count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23) )
# Out:
# [2, 0, 1, 2, 2, 0]
# [2, 2, 3, 1, 0, 2]

# %% [markdown]
# ***

# %% [markdown]
# 3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.
#
# __Ans:-__

# %%
def fib_str(num, lis):
    fibo_lis = [lis[0]]
    
    for i in range(2, num + 1):
        fibo_lis.append(lis[1])
        temp = lis[1]
        lis[1] += lis[0]
        lis[0] = temp
        
    return ', '.join(fibo_lis)
print(fib_str(6, ['n','k']))
print(fib_str(7, ['e','a']))
# Out:
# n, k, kn, knk, knkkn, knkknknk
# e, a, ae, aea, aeaae, aeaaeaea, aeaaeaeaaeaae

# %% [markdown]
# ***

# %% [markdown]
# 4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format:
#
#     "nines:your answer, threes:your answer, ones:your answer"
#
#     You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).
#
# __Ans:-__

# %%
def ones_threes_nines(num):
    nines_needed = num // 9
    num -= 9 * nines_needed
    
    threes_needed = num // 3
    num -= 3 * threes_needed
    
    ones_needed = num
    
    return 'nines: {}, threes: {}, ones : {}'.format(nines_needed, threes_needed, ones_needed)
print(ones_threes_nines(22))
print(ones_threes_nines(26))
print(ones_threes_nines(15))
# Out:
# nines: 2, threes: 1, ones : 1
# nines: 2, threes: 2, ones : 2
# nines: 1, threes: 2, ones : 0

# %% [markdown]
# ***

# %% [markdown]
# 5. Write a non-recursive function that takes an integer n and returns the Fibonacci sequence's value at index n.
#
# __Ans:-__

# %%
def fib(num):
    fib_seq = [0, 1]
    
    if num <= 1:
        return fib_seq[num]
    
    for i in range(2, num + 1):
        temp = fib_seq[1]
        fib_seq[1] += fib_seq[0]
        fib_seq[0] = temp
        
    return fib_seq[1]
print(fib(6))
print(fib(10))
# Out:
# 8
# 55
